# %% [markdown]
# ### Lab 11: Analyzing Climate Data

# %%
# First import python packages for data analysis
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# import date function
from datetime import date

# %%
# Import Methane Dataset into table (dataframe)
CH4 = pd.read_csv('Datasets/Methane_Mauna_Loa_data.csv', skiprows=45).dropna()

# %%
# View the dataframe of Methane Data
CH4.head()
# Out:
#      year  month   decimal  average CH4 (ppb)  average_unc    trend  trend_unc
# 1  1983.0    7.0  1983.542            1625.97         2.26  1634.88       1.45
# 2  1983.0    8.0  1983.625            1628.05         2.88  1635.45       1.39
# 3  1983.0    9.0  1983.708            1638.43         2.34  1636.08       1.32
# 4  1983.0   10.0  1983.792            1644.82         1.50  1636.76       1.24
# 5  1983.0   11.0  1983.875            1642.59         0.73  1637.51       1.16

# %%
# Add column with month and year combined
CH4['DATE']=date(int(np.asarray(CH4['year'])), int(np.asarray(CH4['month'])), 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Add column with month and year combined
# ----> 2 CH4['DATE']=date(int(np.asarray(CH4['year'])), int(np.asarray(CH4['month'])), 1)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
np.asarray(CH4['year'])
# Out:
# array([1983., 1983., 1983., 1983., 1983., 1983., 1984., 1984., 1984.,
#        1984., 1984., 1984., 1984., 1984., 1984., 1984., 1984., 1984.,
#        1985., 1985., 1985., 1985., 1985., 1985., 1985., 1985., 1985.,
#        1985., 1985., 1985., 1986., 1986., 1986., 1986., 1986., 1986.,
#        1986., 1986., 1986., 1986., 1986., 1986., 1987., 1987., 1987.,
#        1987., 1987., 1987., 1987., 1987., 1987., 1987., 1987., 1987.,
#        1988., 1988., 1988., 1988., 1988., 1988., 1988., 1988., 1988.,
#        1988., 1988., 1988., 1989., 1989., 1989., 1989., 1989., 1989.,
#        1989., 1989., 1989., 1989., 1989., 1989., 1990., 1990., 1990.,
#        1990., 1990., 1990., 1990., 1990., 1990., 1990., 1990., 1990.,
#        1991., 1991., 1991., 1991., 1991., 1991., 1991., 1991., 1991.,
#        1991., 1991., 1991., 1992., 1992., 1992., 1992., 1992., 1992.,
#        1992., 1992., 1992., 1992., 1992., 1992., 1993., 1993., 1993.,
# ...

# %%
# View the dataframe of Methane Data
CH4.head()
# Out:
#      year  month   decimal  average CH4 (ppb)  average_unc    trend  trend_unc
# 1  1983.0    7.0  1983.542            1625.97         2.26  1634.88       1.45
# 2  1983.0    8.0  1983.625            1628.05         2.88  1635.45       1.39
# 3  1983.0    9.0  1983.708            1638.43         2.34  1636.08       1.32
# 4  1983.0   10.0  1983.792            1644.82         1.50  1636.76       1.24
# 5  1983.0   11.0  1983.875            1642.59         0.73  1637.51       1.16

# %%
# Plot the average methan data through time
